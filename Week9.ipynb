# %% [markdown]
# <a href="https://colab.research.google.com/github/mrizazul/PCVK_GENAP_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening,
                                area_closing, area_opening)
from skimage.color import rgb2gray

# %%
img = cv.imread('/content/drive/MyDrive/Assets/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc1bbf110>,
#  <matplotlib.image.AxesImage at 0x7febc1f92410>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
img1= cv.imread('/content/drive/MyDrive/Assets/j.png', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc1d470d0>,
#  <matplotlib.image.AxesImage at 0x7febc1c93310>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc1c937d0>,
#  <matplotlib.image.AxesImage at 0x7febc1c30c10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc16ae090>,
#  <matplotlib.image.AxesImage at 0x7febc15b9450>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
img2= cv.imread('/content/drive/MyDrive/Assets/j.png', 0)

p,q= img2.shape

plt.imshow(img2, cmap="gray")

k=5
SED= np.ones((k,k), np.uint8)
constant1=2

imgDilate= np.zeros((p,q), dtype=np.uint8)

for i in range(constant1, p-constant1):
  for j in range(constant1,q-constant1):
    temp= img2[i-constant1:i+constant1+1, j-constant1:j+constant1+1]
    product= temp*SED
    imgDilate[i,j]= np.max(product)
plt.subplot(121), plt.imshow(img2, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgDilate, cmap="gray"), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc2905550>,
#  <matplotlib.image.AxesImage at 0x7febc169eb90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc15ae7d0>,
#  <matplotlib.image.AxesImage at 0x7febc15065d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc15ad990>,
#  <matplotlib.image.AxesImage at 0x7febc145b4d0>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc145b990>,
#  <matplotlib.image.AxesImage at 0x7febc139ee10>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Cross 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0e30e90>,
#  <matplotlib.image.AxesImage at 0x7febc0e44410>,
#  Text(0.5, 1.0, 'Citra Hasil Cross 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Cross 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0d61bd0>,
#  <matplotlib.image.AxesImage at 0x7febc0d30550>,
#  Text(0.5, 1.0, 'Citra Hasil Cross 5x5'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0c37c10>,
#  <matplotlib.image.AxesImage at 0x7febc0c08450>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0c08910>,
#  <matplotlib.image.AxesImage at 0x7febc0b4ddd0>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 5x5'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0abc350>,
#  <matplotlib.image.AxesImage at 0x7febc0aa0a50>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 3x5'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0aa0f10>,
#  <matplotlib.image.AxesImage at 0x7febc09f1550>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 1))
line = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(line), plt.title('Citra Hasil Line 3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7febc0270450>,
#  <matplotlib.image.AxesImage at 0x7febc01adf50>,
#  Text(0.5, 1.0, 'Citra Hasil Line 3'))

# %%
img3= cv.imread('/content/drive/MyDrive/Assets/j.png', 0)

m,n= img3.shape 

plt.imshow(img3, cmap="gray")

k=np.array(([[0,0,1], [0,0,1],[0,0,1]]),dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img3, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-c197799bd353> in <module>()
#      10 imgErode= np.zeros((m,n), dtype=np.uint8)
#      11
# ---> 12 for i in range(constant, m-constant):
#      13   for j in range(constant,n-constant):
#      14     temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
#
# TypeError: only integer scalar arrays can be converted to a scalar index
